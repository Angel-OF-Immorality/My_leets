# %%
s = "bbbaaaba"
t = "aaabbbba"

# %%
s2t, t2s = {}, {}
for x,y in zip(s,t):
    if x in s2t and s2t[x] != y:
        return False
    if y in t2s and t2s[y] != x:
        return False
    s2t[x] = y
    t2s[y] = x

return True
